# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj3p/internship-ai-ml/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing all the libraries required for the analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import math
import numpy as np
import pandas as pd
import statistics
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading the data sheet in the csv format so that we can use the data to perform the desired operations. and the head command displays the first five rows of the data set which are as shown below

# %%
df = pd.read_csv('/content/drive/MyDrive/Bank Customer Churn Prediction.csv')
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# Here we are going to display the data types of the elements in the table

# %%
data_types = df.dtypes
print(data_types)
# Out:
# customer_id           int64
# credit_score          int64
# country              object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# products_number       int64
# credit_card           int64
# active_member         int64
# estimated_salary    float64
# churn                 int64
# dtype: object

# %% [markdown]
# we are classifying the elements into numerical data and categorial data. for performing operations like calculating mean mode and median skewness etc.. we are using numerical data types only

# %%
numeric_data = df.select_dtypes(exclude='object')
categorical_data = df.select_dtypes(include='object')

# %% [markdown]
# Mean of the every numerical variable is displayed using the below command

# %%
# Mean of all the columns in dataframe
df.mean()
# Out:
# customer_id         1.569094e+07
# credit_score        6.505288e+02
# age                 3.892180e+01
# tenure              5.012800e+00
# balance             7.648589e+04
# products_number     1.530200e+00
# credit_card         7.055000e-01
# active_member       5.151000e-01
# estimated_salary    1.000902e+05
# churn               2.037000e-01
# dtype: float64

# %% [markdown]
# Here we are going to display the modes of the numerical variables that are available for us. we are calculating mean mode  for ecah and every individual numerical variable

# %%
df.mode()
# Out:
#       customer_id  credit_score country gender   age  tenure  balance  \
# 0        15565701         850.0  France   Male  37.0     2.0      0.0
# 1        15565706           NaN     NaN    NaN   NaN     NaN      NaN
# 2        15565714           NaN     NaN    NaN   NaN     NaN      NaN
# 3        15565779           NaN     NaN    NaN   NaN     NaN      NaN
# 4        15565796           NaN     NaN    NaN   NaN     NaN      NaN
# ...           ...           ...     ...    ...   ...     ...      ...
# 9995     15815628           NaN     NaN    NaN   NaN     NaN      NaN
# 9996     15815645           NaN     NaN    NaN   NaN     NaN      NaN
# 9997     15815656           NaN     NaN    NaN   NaN     NaN      NaN
# 9998     15815660           NaN     NaN    NaN   NaN     NaN      NaN
# 9999     15815690           NaN     NaN    NaN   NaN     NaN      NaN
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %% [markdown]
# The median of the data is displayed below and now using these values we are going to calculate skewness interquartile range

# %%
statistics.median(df['age'])
# Out:
# 37.0

# %% [markdown]
# ### **skewness**![Screenshot 2024-01-01 170327.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Skewness is the measure of the asymmetry of the distribution of data.
# The data is not symmetrical (i.e) it is skewed towards one side.
# --> Skewness is classified into two types.
#
# Positive Skew
# Negative Skew

# %% [markdown]
# 1.Positively skewed:
#
# In a Positively skewed distribution, the data values are clustered around the left side of the distribution and the right side is longer.
# The mean and median will be greater than the mode in the positive skew.
#
# 2.Negatively skewed
#
# In a Negatively skewed distribution, the data values are clustered around the right side of the distribution and the left side is longer.
# The mean and median will be less than the mode.

# %% [markdown]
# T

# %% [markdown]
# The skew values of all the available variables are presented over here with some having positive skews and some having negative skews

# %%
df.skew()
# Out:
# customer_id         0.001149
# credit_score       -0.071607
# age                 1.011320
# tenure              0.010991
# balance            -0.141109
# products_number     0.745568
# credit_card        -0.901812
# active_member      -0.060437
# estimated_salary    0.002085
# churn               1.471611
# dtype: float64

# %% [markdown]
# Let us consider an example. Now consider age which contains positive skewness which is clear form the graph and also we know the values of mean mode values of the variable age
# Mean>Median>mode so we can justify that age has positive skewness

# %%
#Example of positive skewness
df['age'].plot(kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].mean()
# Out:
# 38.9218

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['age'].mode()
# Out:
# 0    37
# Name: age, dtype: int64

# %% [markdown]
# The graphical reprsentation of skewness mean mode and median of the variable age

# %%
df['age'].plot(kind='density')
plt.axvline(df['age'].mean(), color='red')
plt.axvline(df['age'].median(), color='green')
plt.axvline(df['age'].mode()[0], color='blue')

# %% [markdown]
# Now let us consider another variable to understand the negative skewness

# %%
#Example of negative skewness
df['credit_score'].plot(kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['credit_score'].mean()
# Out:
# 650.5288

# %%
df['credit_score'].median()
# Out:
# 652.0

# %%
df['credit_score'].mode()
# Out:
# 0    850
# Name: credit_score, dtype: int64

# %%
df['credit_score'].plot(kind='density')
plt.axvline(df['credit_score'].mean(), color='red')
plt.axvline(df['credit_score'].median(), color='green')
plt.axvline(df['credit_score'].mode()[0], color='blue')

# %%
df['credit_score'].mode()#Normal Distribution/Symmetric
sns.distplot(df['age'],hist=True,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.displot(df, x="age", hue="churn", kind="kde", multiple="stack")

# %%
#Density of all features
df.plot.density(figsize = (5, 5),linewidth = 3)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### **Kurtosis**

# %% [markdown]
# Kurtosis is the measure of describing the distribution of data.
# This data is distributed in different ways. They are:
# Platykurtic
# Mesokurtic
# Leptokurtic
#
# 1.Platykurtic: The platykurtic shows a distribution with flat tails. Here the data is distributed faltly . The flat tails indicated the small outliers in the distribution.
#
#
# 2.Mesokurtic: In Mesokurtic, the data is widely distributed. It is normally distributed and it also matches normal distribution.
#
#
# 3.Leptokurtic: In leptokurtic, the data is very closely distributed. The height of the peak is greater than width of the peak.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.kurt()
# Out:
# customer_id        -1.196113
# credit_score       -0.425726
# age                 1.395347
# tenure             -1.165225
# balance            -1.489412
# products_number     0.582981
# credit_card        -1.186973
# active_member      -1.996747
# estimated_salary   -1.181518
# churn               0.165671
# dtype: float64

# %%
import seaborn as sns
sns.distplot(df['age'], bins=3)
#for  platkyrutic distribution  use a small number of bins, such as 2 or 3.
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(df['age'], bins=20)
#for  mesokurtic distribution  use a small number of bins, such as 10 or 20
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(df['age'], bins=100)
#for  leptokurtic distribution  use a small number of bins, such as 50 or 100
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ### **Inter Quartile Range(IQR)**

# %% [markdown]
# The interquartile range tells you the spread of the middle half of your distribution.
# Quartiles segment any distribution that’s ordered from low to high into four equal parts. The interquartile range (IQR) contains the second and third quartiles, or the middle half of your data set.
# --> How to calculate IQR?
#
# IQR=Q3-Q1

# %%
for col in numeric_data.columns:
    Q1 = df[col].quantile(.25)
    Q3 = df[col].quantile(.75)
    IQR = Q3 - Q1
    print('IQR of %s : %d' %(col,IQR))
# Out:
# IQR of customer_id : 124705
# IQR of credit_score : 134
# IQR of age : 12
# IQR of tenure : 4
# IQR of balance : 127644
# IQR of products_number : 1
# IQR of credit_card : 1
# IQR of active_member : 1
# IQR of estimated_salary : 98386
# IQR of churn : 0

# %%
#We can also find different percentiles of particular column
df['age'].quantile([0.1,0.2,0.4,0.5])
# Out:
# 0.1    27.0
# 0.2    31.0
# 0.4    35.0
# 0.5    37.0
# Name: age, dtype: float64

# %% [markdown]
# ### **range**

# %% [markdown]
# Range
# The range of data is the difference between the maximum and minimum element in the dataset.

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   age               10000 non-null  int64
#  3   tenure            10000 non-null  int64
#  4   balance           10000 non-null  float64
#  5   products_number   10000 non-null  int64
#  6   credit_card       10000 non-null  int64
#  7   active_member     10000 non-null  int64
#  8   estimated_salary  10000 non-null  float64
#  9   churn             10000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB

# %%
for col in numeric_data.columns:
    range = df[col].max() - df[col].min()
    print('range of %s : %d'%(col,range))
# Out:
# range of customer_id : 249989
# range of credit_score : 500
# range of age : 74
# range of tenure : 10
# range of balance : 250898
# range of products_number : 3
# range of credit_card : 1
# range of active_member : 1
# range of estimated_salary : 199980
# range of churn : 1

# %% [markdown]
# ### **handling outliers**

# %% [markdown]
# outliers are the bad ata that need to be removed

# %%
percentile25 = df['age'].quantile(0.25)
percentile75 = df['age'].quantile(0.75)

# %%
print("75th quartile: ",percentile75)
print("25th quartile: ",percentile25)
# Out:
# 75th quartile:  44.0
# 25th quartile:  32.0

# %%
iqr = percentile75 - percentile25
print ("IQR: ",iqr)
# Out:
# IQR:  12.0

# %%
upper_limit=percentile75+1.5*iqr
print("upper_limit=",upper_limit)
# Out:
# upper_limit= 62.0

# %%
lower_limit=percentile25-1.5*iqr
print("lower_limit=",lower_limit)
# Out:
# lower_limit= 14.0

# %% [markdown]
# Finding Outliers
# So we have by far designed the template for dealing with the outliers and set the threshold value to detect the outliers from the dataset. Now we will use filter conditions on top of the upper and lower limits so that we will get those rows/tuples which are considered to be bad data points.

# %%
df[df['age'] > upper_limit]
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 58       15623944           511    Spain  Female   66       4       0.00
# 85       15805254           652    Spain  Female   75      10       0.00
# 104      15804919           670    Spain  Female   65       1       0.00
# 158      15589975           646   France  Female   73       6   97259.25
# 181      15789669           510   France    Male   65       2       0.00
# ...           ...           ...      ...     ...  ...     ...        ...
# 9753     15705174           656  Germany    Male   68       7  153545.11
# 9765     15777067           445   France    Male   64       2  136770.67
# 9832     15814690           595  Germany  Female   64       2  105736.32
# 9894     15704795           521   France  Female   77       6       0.00
# 9936     15653037           609   France    Male   77       1       0.00
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df[df['age'] > upper_limit].count()
# Out:
# customer_id         359
# credit_score        359
# country             359
# gender              359
# age                 359
# tenure              359
# balance             359
# products_number     359
# credit_card         359
# active_member       359
# estimated_salary    359
# churn               359
# dtype: int64

# %% [markdown]
#  Firstly, we returned the outliers’ rows; then, with the help of the count function, we learned that the total number of rows was 359

# %% [markdown]
# Trimming
# This is the first way we can remove outliers in correct meaning as we don’t give them other certain values or treat them in another way. Trimming removes all the bad data from the dataset just to ensure the quantity of data is not much; otherwise, for analysis, we won’t have much data for ML model development.

# %%
new_df = df[df['age'] < upper_limit]
new_df.shape
# Out:
# (9589, 12)

# %% [markdown]
# comparing

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df['age'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(data = df['age'])

plt.subplot(2,2,3)
sns.histplot(new_df['age'], kde=True)

plt.subplot(2,2,4)
sns.boxplot(data = new_df['age'])

plt.show()

# %% [markdown]
# Inference: Time for some visual comparison where we can see in the 3rd and 4th plots that in the distribution plot, we can see a slight spike in the 40-60 segment of the data compared to the plot before trimming.
#
# The main plot, which lets us know whether the outlier is removed or not, is a boxplot. In the graph, when we compare, it’s visible to the naked eye that almost 99% of the outliers are removed.

# %% [markdown]
# ### **CAPPING**

# %% [markdown]
# Capping is a second way to impute the outliers with some other values. There can be mean, median or mode or any constant value also (that we gonna do here) leads to the condition where there will be no outliers in the dataset

# %%
new_df_cap = df.copy()

new_df_cap['age'] = np.where(
    new_df_cap['age'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['age'] < lower_limit,
        lower_limit,
        new_df_cap['age']
    )
)

# %% [markdown]
# Inference: Here first thing we are doing is to have a copy of the original dataset so that we can use it for another analysis as well. Then we are using the np. where() will help us to impute the upper and lower limit values to both regions of outliers, as one can notice in the code.

# %%
new_df_cap.shape
# Out:
# (10000, 12)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df['age'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(data = df['age'])

plt.subplot(2,2,3)
sns.histplot(new_df_cap['age'], kde=True)

plt.subplot(2,2,4)
sns.boxplot(data = new_df_cap['age'])

plt.show()

# %% [markdown]
# Inference: Time for some comparison, First two plots are the hist and boxplot before we applied the capping technique, so in the boxplot, we can see a lot of outliers/bad data.
#
# On the other hand, after capping, one can see from the naked eye that there are no outliers present in the dataset anymore, and his plot has a slight peak in the 50-70 tile, which stimulates that there are values imputed in that region.
