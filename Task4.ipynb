# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj3p/internship-ai-ml/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the essential libraries for conducting necessary operations on the dataset.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing the dataset in CSV format.

# %%
car=pd.read_csv('/content/Used Car Dataset.csv')

# %% [markdown]
# First five rows of the data set are displayed using ".head()" command.

# %%
car.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %% [markdown]
# ### **Checking Data**

# %% [markdown]
# Checking the elements present in the table and the data types of all the elements present in the table.

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %% [markdown]
# The "describe()" method in Pandas is used to generate descriptive statistics of a DataFrame. This will output a table with various statistics for each numerical column in your DataFrame 'car', including count, mean, standard deviation, minimum, 25th percentile (1st quartile), median (50th percentile or 2nd quartile), 75th percentile (3rd quartile), and maximum.

# %%
car.describe()
# Out:
#         Unnamed: 0         seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count  1553.000000   1553.000000    1553.000000    1550.000000  1.550000e+03
# mean    776.000000     91.480361   52841.931101     236.927277  1.471857e+10
# std     448.456798   2403.424060   40067.800347     585.964295  2.185629e+11
# min       0.000000      4.000000     620.000000       7.810000  5.000000e+00
# 25%     388.000000      5.000000   30000.000000      16.342500  1.197000e+03
# 50%     776.000000      5.000000   49134.000000      18.900000  1.462000e+03
# 75%    1164.000000      5.000000   70000.000000      22.000000  1.995000e+03
# max    1552.000000  67000.000000  810000.000000    3996.000000  3.258640e+12
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count    1.550000e+03  1.549000e+03      1553.000000
# mean     1.471857e+10  1.423989e+04       166.141494
# std      2.185629e+11  9.666241e+04      3478.855090
# min      5.000000e+00  5.000000e+00         1.000000
# ...

# %% [markdown]
# This command is used to count the number of missing values in each column of the DataFrame 'car'. It returns a Series where the index represents the column names, and the values represent the respective count of missing values in each column.

# %%
car.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %% [markdown]
# This command helps identify the total count of duplicate rows in your dataset, contributing to the quality assurance of the data.

# %%
car.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This will output the names of all the columns in the 'car' DataFrame.

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %% [markdown]
# Length of Unique Values

# %% [markdown]
# In the whole data set we are printing the no. of unique values of each coloumn seperately . The no. of unique values for each coloumn are as shown below:

# %%
print('car_name',len(car['car_name'].unique()))
print('registration_year', len(car['registration_year'].unique()))
print('insurance_validity', len(car['insurance_validity'].unique()))
print('fuel_type', len(car['fuel_type'].unique()))
print('seats', len(car['seats'].unique()))
print('kms_driven', len(car['kms_driven'].unique()))
print('ownsership', len(car['ownsership'].unique()))
print('transmission', len(car['transmission'].unique()))
print('manufacturing_year', len(car['manufacturing_year'].unique()))
print('mileage(kmpl)', len(car['mileage(kmpl)'].unique()))
print('engine(cc)', len(car['engine(cc)'].unique()))
print('max_power(bhp)', len(car['max_power(bhp)'].unique()))
print('torque(Nm)', len(car['torque(Nm)'].unique()))
print('price(in lakhs)', len(car['price(in lakhs)'].unique()))
# Out:
# car_name 925
# registration_year 178
# insurance_validity 6
# fuel_type 4
# seats 6
# kms_driven 710
# ownsership 22
# transmission 13
# manufacturing_year 19
# mileage(kmpl) 333
# engine(cc) 148
# max_power(bhp) 148
# torque(Nm) 282
# price(in lakhs) 630

# %% [markdown]
# This command returns the unique values of the particular coloumn, here we used "fuel_type". It returns value in the form of the array, all the values are displayed as shown below.

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', '5 Seats'], dtype=object)

# %% [markdown]
# This command returns the unique values of the particular coloumn, here we used car_name. It returns value in the form of the array all the values are displayed as shown below:

# %%
car['car_name'].unique()
# Out:
# array(['2017 Mercedes-Benz S-Class S400',
#        '2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI',
#        '2018 BMW X1 sDrive 20d xLine', '2019 Kia Seltos GTX Plus',
#        '2019 Skoda Superb LK 1.8 TSI AT', '2017 Honda Jazz 1.2 S i VTEC',
#        '2018 Hyundai Grand i10 1.2 Kappa Sportz BSIV',
#        '2018 Hyundai Creta 1.6 SX',
#        '2015 Mercedes-Benz S-Class S 350 CDI',
#        '2019 Tata Nexon 1.2 Revotron XZ Plus', '2020 Honda City VX CVT',
#        '2021 Renault Duster RXS', '2014 BMW 3 Series 320d Prestige',
#        '2021 Hyundai Venue SX Plus Turbo DCT',
#        '2019 Hyundai Grand i10 1.2 Kappa Sportz BSIV',
#        '2022 Hyundai i20 Asta Opt', '2014 BMW 3 Series 320d Luxury Line',
#        '2018 BMW 3 Series 320d Luxury Line',
#        '2019 Ford Ecosport 1.5 Petrol Titanium Plus BSIV',
#        '2020 Jeep Compass 1.4 Limited Plus',
#        '2021 MG Gloster Savvy 6-Str', '2010 Maruti Swift 1.2 VXi BSII',
# ...

# %% [markdown]
# As there are many unique values on the column "car_name", it is somewhat difficult to display all those values, so we are creating another column named "company" using this "car_name" column

# %%
car['company']=car.car_name.str.split(expand=True)[1]

# %% [markdown]
# After creating new column "company", we are deleting the "car_name" column from the data set.

# %%
del car['car_name']

# %% [markdown]
# This command returns the unique values of the particular coloumn, here we used "company", a newly created coloumn in the data set. It returns value in the form of an array. All the values are displayed as shown below.

# %%
car['company'].unique()
# Out:
# array(['Mercedes-Benz', 'Nissan', 'BMW', 'Kia', 'Skoda', 'Honda',
#        'Hyundai', 'Tata', 'Renault', 'Ford', 'Jeep', 'MG', 'Maruti',
#        'Audi', 'Toyota', 'Jaguar', 'Volkswagen', 'Mahindra', 'Volvo',
#        'Land', 'Isuzu', 'Mitsubishi', 'Porsche', 'Datsun', 'Lexus',
#        'Mini', 'Fiat', 'Lamborghini'], dtype=object)

# %% [markdown]
# After creating new coloumn to check, we are displaying the first five elements of the data set and we observe that the new column "company" has been added to the data set.

# %%
car.head()
# Out:
#    Unnamed: 0 registration_year insurance_validity fuel_type  seats  \
# 0           0            Jul-17      Comprehensive    Petrol      5
# 1           1            Jan-21      Comprehensive    Petrol      5
# 2           2            Sep-18      Comprehensive    Diesel      5
# 3           3            Dec-19      Comprehensive    Petrol      5
# 4           4            Aug-19      Comprehensive    Petrol      5
#
#    kms_driven   ownsership transmission manufacturing_year  mileage(kmpl)  \
# 0       56000  First Owner    Automatic               2017           7.81
# 1       30615  First Owner    Automatic               2020          17.40
# 2       24000  First Owner    Automatic               2018          20.68
# 3       18378  First Owner       Manual               2019          16.50
# 4       44900  First Owner    Automatic               2019          14.67
#
#    engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)        company
# ...

# %% [markdown]
# This command will display all the columns available in the data set and we also see that the newly created "company" also included in the data set.

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'registration_year', 'insurance_validity', 'fuel_type',
#        'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)', 'company'],
#       dtype='object')

# %% [markdown]
# LABEL ENCODING
# Label Encoder class can only be used to encode categorical variables, and the "price(in lakhs)" column is a continuous variable. By encoding the values in the "price(in lakhs)" column, we can use the LabelEncoder class to transform the data into a format that is more suitable for machine learning algorithms.

# %%
# !pip install preprocessing
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.6/349.6 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.1 MB/s eta 0:00:00
# ...
#   Created wheel for nltk: filename=nltk-3.2.4-py3-none-any.whl size=1367709 sha256=d6a453ed92b704df6a8b820d4544817a0e594178bd4dd5a7e80c6f0f10b1a63d
#   Stored in directory: /root/.cache/pip/wheels/0e/8c/42/bcd0934b61ecf4cef964ccc9881888cca0841ec72266e99de1
# Successfully built nltk
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...

# %% [markdown]
# In simple terms, this code converts the categorical values in the 'registration_year' column into numerical labels. Each unique registration year is assigned a unique numerical label, allowing the model to work with this feature effectively.

# %%
import sklearn.preprocessing
label_encoder = sklearn.preprocessing.LabelEncoder()
car['registration_year']=label_encoder.fit_transform(car['registration_year'])
car['insurance_validity'] = label_encoder.fit_transform(car['insurance_validity'])
car['fuel_type'] = label_encoder.fit_transform(car['fuel_type'])
car['seats'] = label_encoder.fit_transform(car['seats'])
car['kms_driven'] = label_encoder.fit_transform(car['kms_driven'])
car['ownsership'] = label_encoder.fit_transform(car['ownsership'])
car['transmission'] = label_encoder.fit_transform(car['transmission'])
car['manufacturing_year'] = label_encoder.fit_transform(car['manufacturing_year'])
car['mileage(kmpl)'] = label_encoder.fit_transform(car['mileage(kmpl)'])
car['engine(cc)'] = label_encoder.fit_transform(car['engine(cc)'])
car['max_power(bhp)'] = label_encoder.fit_transform(car['max_power(bhp)'])
car['torque(Nm)'] = label_encoder.fit_transform(car['torque(Nm)'])
car['price(in lakhs)'] = label_encoder.fit_transform(car['price(in lakhs)'])
#car['company'] = label_encoder.fit_transform(car['comapny'])

# %% [markdown]
# Feature Selection- Correlation

# %% [markdown]
# This code uses the Seaborn and Matplotlib libraries to create a heatmap visualizing the correlation between numerical features in the DataFrame 'car'. The figure size is set to 16 by 10 inches. The colors in the heatmap represent the strength and direction of correlations, while numerical values are annotated for each pair of features. This visualization helps to identify relationships between variables, aiding in data exploration and understanding potential patterns in the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,10))
ax=sns.heatmap(car.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-19-1d1066558baf>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax=sns.heatmap(car.corr(),annot=True)

# %% [markdown]
# This code snippet extracts specific columns from the DataFrame 'car' to create a new DataFrame 'X', representing the input features for a machine learning model. The selected columns include information about the car's registration year, insurance validity, fuel type, seating capacity, kilometers driven, ownership status, transmission type, manufacturing year, mileage, engine capacity, maximum power, and torque. The target variable 'Y' contains the car prices in lakhs. This separation of features and target variable is a common step in preparing data for machine learning tasks, allowing for clearer analysis and model training.

# %%
X=car[['registration_year', 'insurance_validity', 'fuel_type',
       'seats', 'kms_driven', 'ownsership', 'transmission',
       'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
       'torque(Nm)']]
Y=car[['price(in lakhs)']]
X.head()
# Out:
#    registration_year  insurance_validity  fuel_type  seats  kms_driven  \
# 0                 87                   0          3      1         409
# 1                 77                   0          3      1         189
# 2                171                   0          2      1         138
# 3                 51                   0          3      1          92
# 4                 37                   0          3      1         315
#
#    ownsership  transmission  manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0          19            10                   9              0         100
# 1          19            10                  12            130          31
# 2          19            10                  10            213          75
# 3          19            11                  11            111          45
# 4          19            10                  11             73          66
#
#    max_power(bhp)  torque(Nm)
# 0             100          71
# ...

# %% [markdown]
# This command prints the columns of the new data framne "X"

# %%
print(X.columns)
# Out:
# Index(['registration_year', 'insurance_validity', 'fuel_type', 'seats',
#        'kms_driven', 'ownsership', 'transmission', 'manufacturing_year',
#        'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)', 'torque(Nm)'],
#       dtype='object')

# %% [markdown]
# This command prints the columns of the Target Variable which has only one column.

# %%
print(Y.columns)
# Out:
# Index(['price(in lakhs)'], dtype='object')

# %% [markdown]
# EDA

# %% [markdown]
# This code uses Seaborn's lmplot to create a scatter plot with a linear regression line, showing the relationship between the 'mileage(kmpl)' and 'price(in lakhs)' columns from the 'car' DataFrame. The scatter points represent individual cars, and the linear regression line helps visualize any potential correlation or trend between mileage and car price.

# %%
sns.lmplot(x='mileage(kmpl)', y='price(in lakhs)', data=car)

# %% [markdown]
# Data Splitting

# %% [markdown]
# This code uses scikit-learn's train_test_split function to split the dataset into training and testing sets. The features (X) and corresponding target variable (Y) are divided into training (x_train, y_train) and testing (x_test, y_test) sets, with 80% of the data used for training and 20% for testing.

# %%
import sklearn.model_selection
x_train,x_test,y_train,y_test =sklearn.model_selection.train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# These print statements provide information about the dimensions (shape) of the training and testing sets after splitting the data. It shows the number of rows and columns in the Feature sets (x_train and x_test) and the Target Variable sets (y_train and y_test).

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (1242, 12)
# x_test: (311, 12)
# y_train: (1242, 1)
# y_test: (311, 1)

# %% [markdown]
# Model Selection

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %% [markdown]
# Model Training

# %%
clf.fit(x_train,y_train)

# %% [markdown]
# Model Evaluation

# %%
clf.score(x_test,y_test)
# Out:
# 0.6191351697057241

# %%
predict=clf.predict(x_test)
predict
# Out:
# array([[271.7322369 ],
#        [369.31957515],
#        [184.03987644],
#        [436.40511512],
#        [517.22319566],
#        [398.22573426],
#        [256.13765566],
#        [188.61013559],
#        [593.85947212],
#        [ 98.93814026],
#        [213.4537341 ],
#        [ 75.21613921],
#        [510.43585759],
#        [246.51045489],
#        [196.00332927],
#        [169.55384677],
#        [ 51.58988759],
#        [263.91765832],
#        [175.55738002],
#        [223.15431483],
#        [241.82121211],
#        [493.61201578],
#        [345.68124569],
#        [ -4.74178873],
#        [199.4953956 ],
#        [227.99439106],
#        [312.96171901],
#        [307.995794  ],
#        [ 65.93121909],
#        [212.70307056],
#        [268.14245785],
#        [105.1014641 ],
#        [288.64596324],
#        [234.7868447 ],
#        [547.27693227],
#        [269.65857711],
#        [412.91080896],
#        [587.54937216],
#        [428.20400057],
#        [189.37983705],
# ...

# %% [markdown]
# The provided code calculates the root mean squared error (RMSE) between the predicted values ('predict') and the actual values ('y_test'). Additionally, it imports necessary functions from the sklearn.metrics module, such as 'mean_squared_error' and 'mean_absolute_error'. The lower the RMSE, the better the model's predictions align with the true values.

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import math
math.sqrt(mean_squared_error(predict,y_test))
# Out:
# 108.0579496034873

# %% [markdown]
# The code imports the "Lasso" class from scikit-learn's linear_model module. It creates an instance of the Lasso model with a specified regularization parameter 'alpha', which controls the strength of the penalty for large coefficients. In this case, alpha is set to 0.2. The model is trained or "fit" to the training data (x_train, y_train). This involves finding the coefficients that minimize the Lasso regression objective function. The trained model is then used to predict the response variable for new data points ('x_test'), and the predicted values are stored in the variable "y_pred".

# %%
from sklearn.linear_model import Lasso
model = Lasso(alpha=0.2)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([270.77758193, 368.36797326, 184.56464697, 435.0918478 ,
#        515.80720743, 397.06856475, 256.57168197, 188.66398544,
#        592.68157455,  99.24223729, 214.00805119,  75.78118714,
#        512.08290204, 246.49629465, 196.44514491, 170.12817906,
#         51.67031777, 264.01439939, 175.00195605, 223.89510793,
#        241.55118292, 492.64355551, 346.05774305,  -4.56803413,
#        199.96850784, 228.49907686, 312.46120783, 307.39133949,
#         67.00909642, 213.31747857, 268.60533285, 106.11955694,
#        289.06215232, 235.26340061, 546.14251248, 270.1337716 ,
#        413.309722  , 586.84442454, 427.209629  , 189.86364072,
#        133.16897433, 230.03926745, 290.29629604, 383.71447546,
#         73.27931552, 425.10607024, 295.08574529, 456.78290066,
#        204.73041283, 383.31828935, 148.05142222, 406.76390903,
#        414.2914498 , 312.14707403, 245.92285989, 299.33463632,
#        330.55706284, 517.41180304,  61.79818274, 396.5704227 ,
# ...

# %% [markdown]
# This code calculates and prints the R^2 score for your Lasso regression model based on the provided test data (x_test, y_test). The R^2 score will give you an idea of how well your model is performing on the test set. If the R^2 score is closer to 1, it indicates a better fit of the model to the test data.

# %%
model.score(x_test,y_test)
# Out:
# 0.618914490778266

# %% [markdown]
# The code imports the "Ridge" class from scikit-learn's linear_model module. It creates an instance of the Ridge model with a specified regularization parameter 'alpha', which controls the strength of the penalty for large coefficients. In this case, alpha is set to 0.2. The model is trained or "fit" to the training data (x_train, y_train). This involves finding the coefficients that minimize the Ridge regression objective function. The trained model is then used to predict the response variable for new data points ('x_test'), and the predicted values are stored in the variable "y_pred".

# %%
from sklearn.linear_model import Ridge
modell = Ridge(alpha=0.2)
modell.fit(x_train,y_train)
y_pred = modell.predict(x_test)
y_pred
# Out:
# array([[271.69052313],
#        [369.28361441],
#        [184.06028987],
#        [436.36870205],
#        [517.1728527 ],
#        [398.19513881],
#        [256.14820641],
#        [188.62808392],
#        [593.81351008],
#        [ 98.95499664],
#        [213.47768282],
#        [ 75.24268846],
#        [510.47145919],
#        [246.52370276],
#        [196.01456413],
#        [169.57066355],
#        [ 51.59343746],
#        [263.94036159],
#        [175.53771431],
#        [223.18359123],
#        [241.83532226],
#        [493.56943263],
#        [345.69762994],
#        [ -4.73766128],
#        [199.51365686],
#        [228.00968649],
#        [312.94104317],
#        [307.97423344],
#        [ 65.97077152],
#        [212.72527317],
#        [268.15626101],
#        [105.14314993],
#        [288.66836823],
#        [234.81236507],
#        [547.23341105],
#        [269.67049403],
#        [412.93397218],
#        [587.55101304],
#        [428.16323419],
#        [189.40479633],
# ...

# %% [markdown]
# The score method in scikit-learn models, including Ridge regression, calculates the coefficient of determination R^2 of the prediction. The R^2 score is a measure of how well the predictions match the true values. The score ranges from 0 to 1, where 1 indicates a perfect prediction.

# %%
modell.score(x_test,y_test)
# Out:
# 0.6191258000003745
